# %%
import numpy as np
import pandas as pd

df = pd.read_csv("Heart_Disease_Prediction.csv")

df.iloc[:, 3] = df.iloc[:, 3].replace('Presence', 1)
df.iloc[:, 3] = df.iloc[:, 3].replace('Absence', 0)

X = df.iloc[:, :3].values.T.astype(np.float64)
Y = df.iloc[:, 3].values.reshape(1, -1).astype(np.float64)

print(f"Shape of X: {X.shape}")
print(f"Shape of Y: {Y.shape}")

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def leakyrelu(x):
    return np.maximum(0.001 * x, x)

np.random.seed(0)
W1 = np.random.randn(5, 3).astype(np.float64)
b1 = np.zeros((5, 1)).astype(np.float64)
W2 = np.random.randn(1, 5).astype(np.float64)
b2 = np.zeros((1, 1)).astype(np.float64)

learning_rate = 0.01
last_cost = float('inf')
second_last_cost = 0

def forward_propagation(X):
    Z1 = np.dot(W1, X) + b1
    A1 = leakyrelu(Z1)
    Z2 = np.dot(W2, A1) + b2
    A2 = sigmoid(Z2)
    return A1, A2

def compute_cost(A2, Y):
    m = Y.shape[1]
    cost = -np.sum(Y * np.log(A2 + 1e-8) + (1 - Y) * np.log(1 - A2 + 1e-8)) / m
    return np.squeeze(cost)

def backward_propagation(X, Y, A1, A2):
    m = X.shape[1]
    dZ2 = A2 - Y
    dW2 = np.dot(dZ2, A1.T) / m
    db2 = np.sum(dZ2, axis=1, keepdims=True) / m
    dZ1 = np.dot(W2.T, dZ2) * (A1 > 0)  
    dW1 = np.dot(dZ1, X.T) / m
    db1 = np.sum(dZ1, axis=1, keepdims=True) / m
    return dW1, db1, dW2, db2

def gradient_descent(dW1, db1, dW2, db2, learning_rate):
    global W1, W2, b1, b2
    W1 = W1 - learning_rate * dW1
    W2 = W2 - learning_rate * dW2
    b1 = b1 - learning_rate * db1
    b2 = b2 - learning_rate * db2

iteration = 0
while abs(last_cost - second_last_cost) > 0.00001:
    A1, A2 = forward_propagation(X)
    second_last_cost = last_cost
    last_cost = compute_cost(A2, Y)
    print(f"Iteration {iteration}: last_cost = {last_cost}, second_last_cost = {second_last_cost}")
    dW1, db1, dW2, db2 = backward_propagation(X, Y, A1, A2)
    gradient_descent(dW1, db1, dW2, db2, learning_rate)
    iteration += 1

print("Training complete")
# Out:
# Shape of X: (3, 270)
# Shape of Y: (1, 270)
# Iteration 0: last_cost = 10.23371151997354, second_last_cost = inf
# Iteration 1: last_cost = 8.18696921397883, second_last_cost = 10.23371151997354
# Iteration 2: last_cost = 0.7005813482474377, second_last_cost = 8.18696921397883
# Iteration 3: last_cost = 0.7004020653835021, second_last_cost = 0.7005813482474377
# Iteration 4: last_cost = 0.700227414901626, second_last_cost = 0.7004020653835021
# Iteration 5: last_cost = 0.7000571780261975, second_last_cost = 0.700227414901626
# Iteration 6: last_cost = 0.6998911500105383, second_last_cost = 0.7000571780261975
# Iteration 7: last_cost = 0.6997291390753657, second_last_cost = 0.6998911500105383
# Iteration 8: last_cost = 0.6995709654366021, second_last_cost = 0.6997291390753657
# Iteration 9: last_cost = 0.6994164604144935, second_last_cost = 0.6995709654366021
# Iteration 10: last_cost = 0.6992654656167443, second_last_cost = 0.6994164604144935
# Iteration 11: last_cost = 0.699117832189051, second_last_cost = 0.6992654656167443
# Iteration 12: last_cost = 0.6989734201270268, second_last_cost = 0.699117832189051
# Iteration 13: last_cost = 0.6988320976440702, second_last_cost = 0.6989734201270268
# Iteration 14: last_cost = 0.6986937405902374, second_last_cost = 0.6988320976440702
# Iteration 15: last_cost = 0.6985647863229177, second_last_cost = 0.6986937405902374
# Iteration 16: last_cost = 0.6984610917034048, second_last_cost = 0.6985647863229177
# Iteration 17: last_cost = 0.6983587137704544, second_last_cost = 0.6984610917034048
# Iteration 18: last_cost = 0.6982325599126115, second_last_cost = 0.6983587137704544
# Iteration 19: last_cost = 0.6981084578147331, second_last_cost = 0.6982325599126115
# Iteration 20: last_cost = 0.6979863479572384, second_last_cost = 0.6981084578147331
# Iteration 21: last_cost = 0.6978661731708091, second_last_cost = 0.6979863479572384
# Iteration 22: last_cost = 0.6977478785218031, second_last_cost = 0.6978661731708091
# Iteration 23: last_cost = 0.6976314112038811, second_last_cost = 0.6977478785218031
# Iteration 24: last_cost = 0.6975167204354936, second_last_cost = 0.6976314112038811
# Iteration 25: last_cost = 0.6974037573628998, second_last_cost = 0.6975167204354936
# Iteration 26: last_cost = 0.6972924749683972, second_last_cost = 0.6974037573628998
# Iteration 27: last_cost = 0.6971828279834721, second_last_cost = 0.6972924749683972
# Iteration 28: last_cost = 0.6970747728065888, second_last_cost = 0.6971828279834721
# Iteration 29: last_cost = 0.6969690896278533, second_last_cost = 0.6970747728065888
# Iteration 30: last_cost = 0.6968886286682429, second_last_cost = 0.6969690896278533
# Iteration 31: last_cost = 0.6968089411253165, second_last_cost = 0.6968886286682429
# Iteration 32: last_cost = 0.6967300181666817, second_last_cost = 0.6968089411253165
# Iteration 33: last_cost = 0.69665185108867, second_last_cost = 0.6967300181666817
# Iteration 34: last_cost = 0.6965744313139358, second_last_cost = 0.69665185108867
# Iteration 35: last_cost = 0.6964977503891073, second_last_cost = 0.6965744313139358
# Iteration 36: last_cost = 0.6964217999824865, second_last_cost = 0.6964977503891073
# Iteration 37: last_cost = 0.6963465718817994, second_last_cost = 0.6964217999824865
# Iteration 38: last_cost = 0.6962720579919932, second_last_cost = 0.6963465718817994
# Iteration 39: last_cost = 0.6961982503330805, second_last_cost = 0.6962720579919932
# Iteration 40: last_cost = 0.6961251410380304, second_last_cost = 0.6961982503330805
# Iteration 41: last_cost = 0.696052722350704, second_last_cost = 0.6961251410380304
# Iteration 42: last_cost = 0.695980986623835, second_last_cost = 0.696052722350704
# Iteration 43: last_cost = 0.6959099263170521, second_last_cost = 0.695980986623835
# Iteration 44: last_cost = 0.6958395339949456, second_last_cost = 0.6959099263170521
# Iteration 45: last_cost = 0.6957698023251735, second_last_cost = 0.6958395339949456
# Iteration 46: last_cost = 0.6957007240766102, second_last_cost = 0.6957698023251735
# Iteration 47: last_cost = 0.6956322921175334, second_last_cost = 0.6957007240766102
# Iteration 48: last_cost = 0.6955644994138502, second_last_cost = 0.6956322921175334
# Iteration 49: last_cost = 0.6954973390273622, second_last_cost = 0.6955644994138502
# Iteration 50: last_cost = 0.695430804114066, second_last_cost = 0.6954973390273622
# Iteration 51: last_cost = 0.6953648879224905, second_last_cost = 0.695430804114066
# Iteration 52: last_cost = 0.6952995837920719, second_last_cost = 0.6953648879224905
# Iteration 53: last_cost = 0.69523488515156, second_last_cost = 0.6952995837920719
# Iteration 54: last_cost = 0.6951707855174606, second_last_cost = 0.69523488515156
# Iteration 55: last_cost = 0.695107278492511, second_last_cost = 0.6951707855174606
# Iteration 56: last_cost = 0.6950443577641869, second_last_cost = 0.695107278492511
# Iteration 57: last_cost = 0.694982017103242, second_last_cost = 0.6950443577641869
# Iteration 58: last_cost = 0.6949202503622779, second_last_cost = 0.694982017103242
# Iteration 59: last_cost = 0.6948590514743441, second_last_cost = 0.6949202503622779
# Iteration 60: last_cost = 0.6947984144515696, second_last_cost = 0.6948590514743441
# Iteration 61: last_cost = 0.6947383333838196, second_last_cost = 0.6947984144515696
# Iteration 62: last_cost = 0.6946788024373838, second_last_cost = 0.6947383333838196
# Iteration 63: last_cost = 0.6946198158536911, second_last_cost = 0.6946788024373838
# Iteration 64: last_cost = 0.6945613679480503, second_last_cost = 0.6946198158536911
# Iteration 65: last_cost = 0.6945034531084193, second_last_cost = 0.6945613679480503
# Iteration 66: last_cost = 0.6944460657941972, second_last_cost = 0.6945034531084193
# Iteration 67: last_cost = 0.6943892005350438, second_last_cost = 0.6944460657941972
# Iteration 68: last_cost = 0.6943328519297229, second_last_cost = 0.6943892005350438
# Iteration 69: last_cost = 0.6942770146449687, second_last_cost = 0.6943328519297229
# Iteration 70: last_cost = 0.6942216834143768, second_last_cost = 0.6942770146449687
# Iteration 71: last_cost = 0.6941668530373174, second_last_cost = 0.6942216834143768
# Iteration 72: last_cost = 0.6941125183778709, second_last_cost = 0.6941668530373174
# Iteration 73: last_cost = 0.694058674363785, second_last_cost = 0.6941125183778709
# Iteration 74: last_cost = 0.6940053159854543, second_last_cost = 0.694058674363785
# Iteration 75: last_cost = 0.6939524382949185, second_last_cost = 0.6940053159854543
# Iteration 76: last_cost = 0.6939000364048833, second_last_cost = 0.6939524382949185
# Iteration 77: last_cost = 0.6938481054877589, second_last_cost = 0.6939000364048833
# Iteration 78: last_cost = 0.6937966407747201, second_last_cost = 0.6938481054877589
# Iteration 79: last_cost = 0.6937456375547829, second_last_cost = 0.6937966407747201
# Iteration 80: last_cost = 0.6936950911739018, second_last_cost = 0.6937456375547829
# Iteration 81: last_cost = 0.6936449970340834, second_last_cost = 0.6936950911739018
# Iteration 82: last_cost = 0.6935953505925189, second_last_cost = 0.6936449970340834
# Iteration 83: last_cost = 0.6935461473607327, second_last_cost = 0.6935953505925189
# Iteration 84: last_cost = 0.6934973829037487, second_last_cost = 0.6935461473607327
# Iteration 85: last_cost = 0.6934490528392729, second_last_cost = 0.6934973829037487
# Iteration 86: last_cost = 0.6934011528368912, second_last_cost = 0.6934490528392729
# Iteration 87: last_cost = 0.6933536786172835, second_last_cost = 0.6934011528368912
# Iteration 88: last_cost = 0.6933066259514538, second_last_cost = 0.6933536786172835
# Iteration 89: last_cost = 0.6932599906599737, second_last_cost = 0.6933066259514538
# Iteration 90: last_cost = 0.6932137686122417, second_last_cost = 0.6932599906599737
# Iteration 91: last_cost = 0.693167955725756, second_last_cost = 0.6932137686122417
# Iteration 92: last_cost = 0.6931225479654024, second_last_cost = 0.693167955725756
# Iteration 93: last_cost = 0.6930775413427539, second_last_cost = 0.6931225479654024
# Iteration 94: last_cost = 0.6930329319153857, second_last_cost = 0.6930775413427539
# Iteration 95: last_cost = 0.692988715786202, second_last_cost = 0.6930329319153857
# Iteration 96: last_cost = 0.6929448891027752, second_last_cost = 0.692988715786202
# Iteration 97: last_cost = 0.6929014480566992, second_last_cost = 0.6929448891027752
# Iteration 98: last_cost = 0.6928583888829523, second_last_cost = 0.6929014480566992
# Iteration 99: last_cost = 0.692815707859274, second_last_cost = 0.6928583888829523
# Iteration 100: last_cost = 0.6927734013055533, second_last_cost = 0.692815707859274
# Iteration 101: last_cost = 0.6927314655832271, second_last_cost = 0.6927734013055533
# Iteration 102: last_cost = 0.6926898970946905, second_last_cost = 0.6927314655832271
# Iteration 103: last_cost = 0.6926486922827177, second_last_cost = 0.6926898970946905
# Iteration 104: last_cost = 0.6926078476298939, second_last_cost = 0.6926486922827177
# Iteration 105: last_cost = 0.6925673596580564, second_last_cost = 0.6926078476298939
# Iteration 106: last_cost = 0.692527224927748, second_last_cost = 0.6925673596580564
# Iteration 107: last_cost = 0.6924874400376778, second_last_cost = 0.692527224927748
# Iteration 108: last_cost = 0.692448001624193, second_last_cost = 0.6924874400376778
# Iteration 109: last_cost = 0.6924089063607599, second_last_cost = 0.692448001624193
# Iteration 110: last_cost = 0.6923701509574549, second_last_cost = 0.6924089063607599
# Iteration 111: last_cost = 0.692331732160463, second_last_cost = 0.6923701509574549
# Iteration 112: last_cost = 0.6922936467515863, second_last_cost = 0.692331732160463
# Iteration 113: last_cost = 0.692255891547761, second_last_cost = 0.6922936467515863
# Iteration 114: last_cost = 0.6922184634005825, second_last_cost = 0.692255891547761
# Iteration 115: last_cost = 0.6921813591958392, second_last_cost = 0.6922184634005825
# Iteration 116: last_cost = 0.6921445758530538, second_last_cost = 0.6921813591958392
# Iteration 117: last_cost = 0.6921081103250336, second_last_cost = 0.6921445758530538
# Iteration 118: last_cost = 0.6920719595974274, second_last_cost = 0.6921081103250336
# Iteration 119: last_cost = 0.6920361206882901, second_last_cost = 0.6920719595974274
# Iteration 120: last_cost = 0.6920005906476566, second_last_cost = 0.6920361206882901
# Iteration 121: last_cost = 0.6919653665571195, second_last_cost = 0.6920005906476566
# Iteration 122: last_cost = 0.6919304455294174, second_last_cost = 0.6919653665571195
# Iteration 123: last_cost = 0.6918958247080281, second_last_cost = 0.6919304455294174
# Iteration 124: last_cost = 0.6918615012667692, second_last_cost = 0.6918958247080281
# Iteration 125: last_cost = 0.6918274724094051, second_last_cost = 0.6918615012667692
# Iteration 126: last_cost = 0.6917937353692613, second_last_cost = 0.6918274724094051
# Iteration 127: last_cost = 0.6917602874088443, second_last_cost = 0.6917937353692613
# Iteration 128: last_cost = 0.6917271258194679, second_last_cost = 0.6917602874088443
# Iteration 129: last_cost = 0.6916942479208864, second_last_cost = 0.6917271258194679
# Iteration 130: last_cost = 0.6916616510609324, second_last_cost = 0.6916942479208864
# Iteration 131: last_cost = 0.6916293326151614, second_last_cost = 0.6916616510609324
# Iteration 132: last_cost = 0.6915972899865028, second_last_cost = 0.6916293326151614
# Iteration 133: last_cost = 0.6915655206049148, second_last_cost = 0.6915972899865028
# Iteration 134: last_cost = 0.6915340219270466, second_last_cost = 0.6915655206049148
# Iteration 135: last_cost = 0.6915027914359049, second_last_cost = 0.6915340219270466
# Iteration 136: last_cost = 0.6914718266405253, second_last_cost = 0.6915027914359049
# Iteration 137: last_cost = 0.6914411250756514, second_last_cost = 0.6914718266405253
# Iteration 138: last_cost = 0.6914106843014155, second_last_cost = 0.6914411250756514
# Iteration 139: last_cost = 0.6913805019030268, second_last_cost = 0.6914106843014155
# Iteration 140: last_cost = 0.6913505754904639, second_last_cost = 0.6913805019030268
# Iteration 141: last_cost = 0.6913209026981714, second_last_cost = 0.6913505754904639
# Iteration 142: last_cost = 0.6912914811847622, second_last_cost = 0.6913209026981714
# Iteration 143: last_cost = 0.6912623086327238, second_last_cost = 0.6912914811847622
# Iteration 144: last_cost = 0.6912333827481285, second_last_cost = 0.6912623086327238
# Iteration 145: last_cost = 0.6912047012603504, second_last_cost = 0.6912333827481285
# Iteration 146: last_cost = 0.6911762619217835, second_last_cost = 0.6912047012603504
# Iteration 147: last_cost = 0.6911480625075667, second_last_cost = 0.6911762619217835
# Iteration 148: last_cost = 0.6911201008153114, second_last_cost = 0.6911480625075667
# Iteration 149: last_cost = 0.6910923746648343, second_last_cost = 0.6911201008153114
# Iteration 150: last_cost = 0.6910648818978931, second_last_cost = 0.6910923746648343
# Iteration 151: last_cost = 0.6910376203779272, second_last_cost = 0.6910648818978931
# Iteration 152: last_cost = 0.6910105879898013, second_last_cost = 0.6910376203779272
# Iteration 153: last_cost = 0.690983782639554, second_last_cost = 0.6910105879898013
# Iteration 154: last_cost = 0.6909572022541486, second_last_cost = 0.690983782639554
# Iteration 155: last_cost = 0.6909308447812289, second_last_cost = 0.6909572022541486
# Iteration 156: last_cost = 0.6909047081888781, second_last_cost = 0.6909308447812289
# Iteration 157: last_cost = 0.6908787904653804, second_last_cost = 0.6909047081888781
# Iteration 158: last_cost = 0.6908530896189876, second_last_cost = 0.6908787904653804
# Iteration 159: last_cost = 0.6908276036776883, second_last_cost = 0.6908530896189876
# Iteration 160: last_cost = 0.6908023306889799, second_last_cost = 0.6908276036776883
# Iteration 161: last_cost = 0.6907772687196445, second_last_cost = 0.6908023306889799
# Iteration 162: last_cost = 0.6907524158555283, second_last_cost = 0.6907772687196445
# Iteration 163: last_cost = 0.690727770201323, second_last_cost = 0.6907524158555283
# Iteration 164: last_cost = 0.6907033298803523, second_last_cost = 0.690727770201323
# Iteration 165: last_cost = 0.6906790930343585, second_last_cost = 0.6907033298803523
# Iteration 166: last_cost = 0.6906550578232947, second_last_cost = 0.6906790930343585
# Iteration 167: last_cost = 0.6906312224251194, second_last_cost = 0.6906550578232947
# Iteration 168: last_cost = 0.6906075850355923, second_last_cost = 0.6906312224251194
# Iteration 169: last_cost = 0.6905841438680748, second_last_cost = 0.6906075850355923
# Iteration 170: last_cost = 0.6905608971533332, second_last_cost = 0.6905841438680748
# Iteration 171: last_cost = 0.6905378431393429, second_last_cost = 0.6905608971533332
# Iteration 172: last_cost = 0.690514980091097, second_last_cost = 0.6905378431393429
# Iteration 173: last_cost = 0.6904923062904172, second_last_cost = 0.690514980091097
# Iteration 174: last_cost = 0.6904698200357666, second_last_cost = 0.6904923062904172
# Iteration 175: last_cost = 0.6904475196420656, second_last_cost = 0.6904698200357666
# Iteration 176: last_cost = 0.6904254034405101, second_last_cost = 0.6904475196420656
# Iteration 177: last_cost = 0.6904034697783923, second_last_cost = 0.6904254034405101
# Iteration 178: last_cost = 0.6903817170189239, second_last_cost = 0.6904034697783923
# Iteration 179: last_cost = 0.6903601435410616, second_last_cost = 0.6903817170189239
# Iteration 180: last_cost = 0.6903387477393342, second_last_cost = 0.6903601435410616
# Iteration 181: last_cost = 0.6903175280236741, second_last_cost = 0.6903387477393342
# Iteration 182: last_cost = 0.6902964828192482, second_last_cost = 0.6903175280236741
# Iteration 183: last_cost = 0.6902756105662934, second_last_cost = 0.6902964828192482
# Iteration 184: last_cost = 0.690254909719953, second_last_cost = 0.6902756105662934
# Iteration 185: last_cost = 0.6902343787501155, second_last_cost = 0.690254909719953
# Iteration 186: last_cost = 0.6902140161412559, second_last_cost = 0.6902343787501155
# Iteration 187: last_cost = 0.6901938203922784, second_last_cost = 0.6902140161412559
# Iteration 188: last_cost = 0.6901737900163616, second_last_cost = 0.6901938203922784
# Iteration 189: last_cost = 0.6901539235408056, second_last_cost = 0.6901737900163616
# Iteration 190: last_cost = 0.690134219506881, second_last_cost = 0.6901539235408056
# Iteration 191: last_cost = 0.6901146764696802, second_last_cost = 0.690134219506881
# Iteration 192: last_cost = 0.6900952929979697, second_last_cost = 0.6901146764696802
# Iteration 193: last_cost = 0.6900760676740448, second_last_cost = 0.6900952929979697
# Iteration 194: last_cost = 0.6900569990935878, second_last_cost = 0.6900760676740448
# Iteration 195: last_cost = 0.6900380858655238, second_last_cost = 0.6900569990935878
# Iteration 196: last_cost = 0.6900193266118833, second_last_cost = 0.6900380858655238
# Iteration 197: last_cost = 0.6900007199676625, second_last_cost = 0.6900193266118833
# Iteration 198: last_cost = 0.6899822645806881, second_last_cost = 0.6900007199676625
# Iteration 199: last_cost = 0.6899639591114822, second_last_cost = 0.6899822645806881
# Iteration 200: last_cost = 0.6899458022331293, second_last_cost = 0.6899639591114822
# Iteration 201: last_cost = 0.6899277926311451, second_last_cost = 0.6899458022331293
# Iteration 202: last_cost = 0.689909929003347, second_last_cost = 0.6899277926311451
# Iteration 203: last_cost = 0.6898922100597257, second_last_cost = 0.689909929003347
# Iteration 204: last_cost = 0.6898746345223195, second_last_cost = 0.6898922100597257
# Iteration 205: last_cost = 0.6898572011250881, second_last_cost = 0.6898746345223195
# Iteration 206: last_cost = 0.6898399086137903, second_last_cost = 0.6898572011250881
# Iteration 207: last_cost = 0.6898227557458616, second_last_cost = 0.6898399086137903
# Iteration 208: last_cost = 0.6898057412902939, second_last_cost = 0.6898227557458616
# Iteration 209: last_cost = 0.6897888640275166, second_last_cost = 0.6898057412902939
# Iteration 210: last_cost = 0.6897721227492783, second_last_cost = 0.6897888640275166
# Iteration 211: last_cost = 0.6897555162585326, second_last_cost = 0.6897721227492783
# Iteration 212: last_cost = 0.689739043369321, second_last_cost = 0.6897555162585326
# Iteration 213: last_cost = 0.6897227029066609, second_last_cost = 0.689739043369321
# Iteration 214: last_cost = 0.6897064937064336, second_last_cost = 0.6897227029066609
# Iteration 215: last_cost = 0.6896904146152735, second_last_cost = 0.6897064937064336
# Iteration 216: last_cost = 0.6896744644904577, second_last_cost = 0.6896904146152735
# Iteration 217: last_cost = 0.6896586421998, second_last_cost = 0.6896744644904577
# Iteration 218: last_cost = 0.6896429466215425, second_last_cost = 0.6896586421998
# Iteration 219: last_cost = 0.6896273766442503, second_last_cost = 0.6896429466215425
# Iteration 220: last_cost = 0.6896119311667075, second_last_cost = 0.6896273766442503
# Iteration 221: last_cost = 0.6895966090978144, second_last_cost = 0.6896119311667075
# Iteration 222: last_cost = 0.6895814093564845, second_last_cost = 0.6895966090978144
# Iteration 223: last_cost = 0.6895663308715453, second_last_cost = 0.6895814093564845
# Iteration 224: last_cost = 0.6895513725816379, second_last_cost = 0.6895663308715453
# Iteration 225: last_cost = 0.689536533435118, second_last_cost = 0.6895513725816379
# Iteration 226: last_cost = 0.6895218123899606, second_last_cost = 0.689536533435118
# Iteration 227: last_cost = 0.6895072084136615, second_last_cost = 0.6895218123899606
# Iteration 228: last_cost = 0.6894927204831441, second_last_cost = 0.6895072084136615
# Iteration 229: last_cost = 0.6894783475846649, second_last_cost = 0.6894927204831441
# Iteration 230: last_cost = 0.68946408871372, second_last_cost = 0.6894783475846649
# Iteration 231: last_cost = 0.6894499428749543, second_last_cost = 0.68946408871372
# Iteration 232: last_cost = 0.6894359090820701, second_last_cost = 0.6894499428749543
# Iteration 233: last_cost = 0.6894219863577372, second_last_cost = 0.6894359090820701
# Iteration 234: last_cost = 0.6894081737335053, second_last_cost = 0.6894219863577372
# Iteration 235: last_cost = 0.6893944702497147, second_last_cost = 0.6894081737335053
# Iteration 236: last_cost = 0.6893808749554109, second_last_cost = 0.6893944702497147
# Iteration 237: last_cost = 0.6893673869082576, second_last_cost = 0.6893808749554109
# Iteration 238: last_cost = 0.6893540051744531, second_last_cost = 0.6893673869082576
# Iteration 239: last_cost = 0.6893407288286462, second_last_cost = 0.6893540051744531
# Iteration 240: last_cost = 0.6893275569538522, second_last_cost = 0.6893407288286462
# Iteration 241: last_cost = 0.6893144886413717, second_last_cost = 0.6893275569538522
# Iteration 242: last_cost = 0.6893015229907103, second_last_cost = 0.6893144886413717
# Iteration 243: last_cost = 0.6892886591094969, second_last_cost = 0.6893015229907103
# Iteration 244: last_cost = 0.6892758961134051, second_last_cost = 0.6892886591094969
# Iteration 245: last_cost = 0.6892632331260747, second_last_cost = 0.6892758961134051
# Iteration 246: last_cost = 0.6892506692790343, second_last_cost = 0.6892632331260747
# Iteration 247: last_cost = 0.6892382037116243, second_last_cost = 0.6892506692790343
# Iteration 248: last_cost = 0.6892258355709211, second_last_cost = 0.6892382037116243
# Iteration 249: last_cost = 0.6892135640116621, second_last_cost = 0.6892258355709211
# Iteration 250: last_cost = 0.689201388196171, second_last_cost = 0.6892135640116621
# Iteration 251: last_cost = 0.6891893072942851, second_last_cost = 0.689201388196171
# Iteration 252: last_cost = 0.6891773204832823, second_last_cost = 0.6891893072942851
# Iteration 253: last_cost = 0.6891654269478088, second_last_cost = 0.6891773204832823
# Iteration 254: last_cost = 0.6891536258798088, second_last_cost = 0.6891654269478088
# Iteration 255: last_cost = 0.6891419164784536, second_last_cost = 0.6891536258798088
# Iteration 256: last_cost = 0.6891302979500723, second_last_cost = 0.6891419164784536
# Iteration 257: last_cost = 0.6891187695080832, second_last_cost = 0.6891302979500723
# Iteration 258: last_cost = 0.6891073303729244, second_last_cost = 0.6891187695080832
# Iteration 259: last_cost = 0.6890959797719888, second_last_cost = 0.6891073303729244
# Iteration 260: last_cost = 0.6890847169395552, second_last_cost = 0.6890959797719888
# Iteration 261: last_cost = 0.6890735411167233, second_last_cost = 0.6890847169395552
# Iteration 262: last_cost = 0.6890624515513489, second_last_cost = 0.6890735411167233
# Iteration 263: last_cost = 0.6890514474979788, second_last_cost = 0.6890624515513489
# Iteration 264: last_cost = 0.6890405282177863, second_last_cost = 0.6890514474979788
# Iteration 265: last_cost = 0.6890296929785098, second_last_cost = 0.6890405282177863
# Iteration 266: last_cost = 0.6890189410543885, second_last_cost = 0.6890296929785098
# Iteration 267: last_cost = 0.6890082717261018, second_last_cost = 0.6890189410543885
# Iteration 268: last_cost = 0.6889976842807066, second_last_cost = 0.6890082717261018
# Iteration 269: last_cost = 0.688987178011579, second_last_cost = 0.6889976842807066
# Iteration 270: last_cost = 0.6889767522183518, second_last_cost = 0.688987178011579
# Iteration 271: last_cost = 0.6889664062068569, second_last_cost = 0.6889767522183518
# Iteration 272: last_cost = 0.6889561392890662, second_last_cost = 0.6889664062068569
# Iteration 273: last_cost = 0.688945950783033, second_last_cost = 0.6889561392890662
# Iteration 274: last_cost = 0.6889358400128353, second_last_cost = 0.688945950783033
# Iteration 275: last_cost = 0.6889258063085186, second_last_cost = 0.6889358400128353
# Iteration 276: last_cost = 0.688915849006039, second_last_cost = 0.6889258063085186
# Training complete
# C:\Users\anula\AppData\Local\Temp\ipykernel_20032\858495126.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.iloc[:, 3] = df.iloc[:, 3].replace('Absence', 0)
# C:\Users\anula\AppData\Local\Temp\ipykernel_20032\858495126.py:16: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
